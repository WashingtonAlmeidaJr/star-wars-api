# %%
#Personagenss do filme Starwars

# %%
#importando bibliotecas

import requests
import json
import pandas as pd
from pandas import json_normalize

# %%
#tabela concatenada
tabela_final=pd.DataFrame()
pagina=1


#loop para passar pelas paginas da api de personagens
while pagina in range(5):
    #fazer requisição da api 
    link=f'https://swapi.dev/api/people/?page={pagina}'
    request=requests.get(link)
    request_json=request.json()
    tabela=pd.DataFrame(request_json['results'])
    tabela_final=pd.concat([tabela_final,tabela])
    pagina=pagina+1
tabela_final
# Out:
#                     name   height     mass     hair_color        skin_color  \
# 0         Luke Skywalker      172       77          blond              fair
# 1                  C-3PO      167       75            n/a              gold
# 2                  R2-D2       96       32            n/a       white, blue
# 3            Darth Vader      202      136           none             white
# 4            Leia Organa      150       49          brown             light
# 5              Owen Lars      178      120    brown, grey             light
# 6     Beru Whitesun lars      165       75          brown             light
# 7                  R5-D4       97       32            n/a        white, red
# 8      Biggs Darklighter      183       84          black             light
# 9         Obi-Wan Kenobi      182       77  auburn, white              fair
# 0       Anakin Skywalker      188       84          blond              fair
# ...
